# %%
import numpy as np
import pandas as pd
import math
import random
import time
import os
import sys
from scipy.spatial import distance
from sklearn import cluster
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
numericalDF = pd.read_csv('numericalData.csv')
columnas = ['directores','criticas','duracion','genero','actores1','actores2','actores3','rostros',
            'scores','gross','budget']
del numericalDF['Unnamed: 0']

for i in columnas:
    numericalDF.loc[numericalDF[i] == 0, i] = numericalDF[i].mean()
numericalDF.head()

test_point = numericalDF.head(20).values
train_set = numericalDF.tail(len(numericalDF)-20).values
#print("Datos de entrenaiento: \n{}\n\nDato de prueba:\n{}\n".format(train_set, test_point))


from sklearn import cluster
from matplotlib import pyplot as plt
# %matplotlib inline

num_clusters = 2
k_means = cluster.KMeans(n_clusters=num_clusters, init='random')
k_means.fit(train_set) 
print("Prototipos de clase (centroides):\n", k_means.cluster_centers_)

fig = plt.figure(figsize=(8, 5))
colors = ['#ff0000', '#00ff00', '#0000ff', '#ff00ff', '#00ffff', '#ffff00', '#f6ff00', 
              '#2f800f', '#a221b5', '#21b5ac', '#b1216c']
for k in range(num_clusters):
    my_members = k_means.labels_ == k
    plt.plot(train_set[my_members, 0], train_set[my_members, 1], 'o', 
             markeredgecolor='k', markerfacecolor=colors[k], markersize=4)
    plt.plot(k_means.cluster_centers_[k][0], k_means.cluster_centers_[k][1], 'o', 
             markeredgecolor='k', markerfacecolor=colors[k], markersize=6)

plt.show()
# Out:
# Prototipos de clase (centroides):
#  [[ 0.00982683  0.01383783  0.01467988  0.01328462  0.01053319  0.01182233
#    0.01221767  0.01064956  0.01638976  0.01095505  0.00281788  2.        ]
#  [ 0.01119567  0.00930846  0.01332072  0.01072479  0.0099232   0.01096135
#    0.01124681  0.01164559  0.01272093  0.00773263  0.00275854  1.        ]]

# %%
LARGER_DISTANCE = sys.maxsize

k_neighs = 5 # 5 vecinos... aunque tomaremos sólo el más cercano
neighbors_dists = [LARGER_DISTANCE] * k_neighs
neighbors = [0] * k_neighs
for j in range(20):
    for i in range(len(train_set)):
        dist = distance.euclidean(train_set[i], test_point[j])
        for k in range(k_neighs):
            if (dist < neighbors_dists[k]) :
                for j in range(k_neighs-1, k, -1):
                    neighbors_dists[j] = neighbors_dists[j-1]
                    neighbors[j] = neighbors[j-1] 
                neighbors_dists[k] = dist
                neighbors[k] = i
                break
            
print("Los {} vecinos más próximos son:".format(k_neighs))
for k in range(k_neighs):
    clase = k_means.labels_1[neighbors[k]]
    print("Vecino {}: {}, dist={}, clase={}"
          .format(k, neighbors[k], neighbors_dists[k], 
                  clase))
print("\nEl nuevo punto es asignado a la clase", k_means.labels_[neighbors[0]])
# Out:
# Los 5 vecinos más próximos son:
# Vecino 0: 9, dist=0.002008003102390763, clase=1
# Vecino 1: 101, dist=0.003121318035241983, clase=0
# Vecino 2: 46, dist=0.004512709447185624, clase=1
# Vecino 3: 5, dist=0.005202120726999198, clase=1
# Vecino 4: 9, dist=0.0053940538389108915, clase=1
#
# El nuevo punto es asignado a la clase 1
